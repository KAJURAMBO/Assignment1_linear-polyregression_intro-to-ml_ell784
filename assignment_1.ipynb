# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
import math
data=pd.read_csv('train.csv')
X=data['x']
Y=data['y']
X_20=X.loc[0:19]
Y_20=Y.loc[0:19]

# X_20.shape## As the dimension is 100, but linear regression trainning need atleast 1 dimension
# Y_20.shape
# X_20.ndim
# Y_20.ndim ## 1 ...Cant train linear regression model so we need to give dimension
x_train = X_20.values.reshape(-1,1)
y_train = Y_20.values.reshape(-1,1)
x_full = X.values.reshape(-1,1)
y_full = Y.values.reshape(-1,1)


M=25
Mean_square_error=[]

for i in range(M):
        polynomial_features = PolynomialFeatures(degree = i)
        X_poly = polynomial_features.fit_transform(x_train)
        
        polynomial_reg_model=LinearRegression()
        polynomial_reg_model.fit(X_poly,y_train)
        y_predicted = polynomial_reg_model.predict(X_poly)
        
        
        plt.figure(figsize=(5,5))
        fig, ax = plt.subplots()
        plt.title(f"Graph for M ={i}")
        plt.scatter(X_20,Y_20,label='Data points')
        plt.xlabel("X")
        plt.ylabel("Y")
        
        plt.scatter(X_20,y_predicted,label='Predicted',c="red")
        legend = ax.legend(loc='best', fontsize='x-large')
        plt.show
        MSE = mean_squared_error(Y_20, y_predicted)
        RMSE = math.sqrt(MSE)
        Mean_square_error.append(RMSE)
        print("Root Mean Square Error:",RMSE)
Iterations_M= (np.linspace(1,M,num=M,dtype="int"))
plt.figure(figsize = (12, 5))
plt.plot(Iterations_M, Mean_square_error, 'green')
plt.title("Error vs M")
plt.xlabel('Iterations_M')
plt.ylabel('RMSE')
plt.xticks(np.arange(1,M+1))
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.") 
plt.show()
# Out:
# Root Mean Square Error: 247.0541643191767
# Root Mean Square Error: 211.12447248939546
# Root Mean Square Error: 154.8615544456756
# Root Mean Square Error: 96.24902022347398
# Root Mean Square Error: 46.02383183717053
# Root Mean Square Error: 22.935950053185138
# Root Mean Square Error: 18.149825822102095
# Root Mean Square Error: 18.145050251430355
# Root Mean Square Error: 17.97025665371971
# Root Mean Square Error: 16.88613992844558
# C:\Users\rahma\AppData\Local\Temp\ipykernel_21748\3763024110.py:36: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(5,5))
# Root Mean Square Error: 15.031923356337714
# Root Mean Square Error: 14.43520019221988
# Root Mean Square Error: 14.190431227165373
# Root Mean Square Error: 12.44562579439699
# Root Mean Square Error: 9.098173737132752
# Root Mean Square Error: 9.088296464276995
# Root Mean Square Error: 8.903819970784388
# Root Mean Square Error: 8.172395895919673
# Root Mean Square Error: 8.032758734543286
# Root Mean Square Error: 3.4338944369686755e-05
# Root Mean Square Error: 7.15648966042862e-05
# Root Mean Square Error: 8.031899199286091e-05
# Root Mean Square Error: 1.0678427643157234e-05
# Root Mean Square Error: 0.0001136633059550557
# Root Mean Square Error: 0.0002752588799809507

# %%
M=25
Mean_square_error_full=[]

for i in range(M):
        polynomial_features = PolynomialFeatures(degree = i)
        X_poly_full = polynomial_features.fit_transform(x_full)
        
        polynomial_reg_model=LinearRegression()
        polynomial_reg_model.fit(X_poly_full,y_full)
        y_predicted_full = polynomial_reg_model.predict(X_poly_full)
        
        
        plt.figure(figsize=(5,5))
        fig, ax = plt.subplots()
        plt.title(f"Graph for M ={i}")
        plt.scatter(X,Y,label='Full Data Points')
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.scatter(X,y_predicted_full,label='Predicted',c="red")
        legend = ax.legend(loc='best', fontsize='x-large')
        plt.show
        MSE_full = mean_squared_error(Y, y_predicted_full)
        RMSE = math.sqrt(MSE_full)
        Mean_square_error_full.append(RMSE)
        print("Root Mean Square Error:",RMSE)
Iterations_M_full= (np.linspace(1,M,num=M,dtype="int"))
plt.figure(figsize = (12, 5))
plt.plot(Iterations_M_full, Mean_square_error_full, 'green')
plt.title("Error vs M")
plt.xlabel('Iterations_M')
plt.ylabel('RMSE')
plt.xticks(np.arange(1,M+1))
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.") 
plt.show()
# Out:
# Root Mean Square Error: 298.8398296781834
# Root Mean Square Error: 237.58781279272927
# Root Mean Square Error: 231.6178705136389
# Root Mean Square Error: 98.3836525965776
# Root Mean Square Error: 95.48674442022723
# Root Mean Square Error: 25.514474057246286
# Root Mean Square Error: 25.51339401238804
# Root Mean Square Error: 19.080837936561306
# Root Mean Square Error: 18.896599506145428
# Root Mean Square Error: 18.44095661320482
# C:\Users\rahma\AppData\Local\Temp\ipykernel_21748\867519444.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(5,5))
# Root Mean Square Error: 18.426066987822978
# Root Mean Square Error: 18.292977625412664
# Root Mean Square Error: 18.129167959353495
# Root Mean Square Error: 18.097740132228925
# Root Mean Square Error: 17.98890521328133
# Root Mean Square Error: 17.701502469764975
# Root Mean Square Error: 17.636264919084795
# Root Mean Square Error: 17.631992921648482
# Root Mean Square Error: 17.14342606527487
# Root Mean Square Error: 17.123503722628623
# Root Mean Square Error: 16.99851002074796
# Root Mean Square Error: 16.07430526804454
# Root Mean Square Error: 16.034051311642276
# Root Mean Square Error: 15.995425903361317
# Root Mean Square Error: 15.99527941942065

# %%
fig, ax = plt.subplots(figsize = (12, 5))
plt.plot(Iterations_M_full, Mean_square_error_full, 'red',label='Full_data=70')
plt.plot(Iterations_M, Mean_square_error, 'green',label='Fewer data=20')
plt.title("Error vs M")
plt.xlabel('Iterations_M')
plt.ylabel('RMSE')
M=26
plt.xticks(np.arange(1,M+1))
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.") 
legend = ax.legend(loc='best', fontsize='x-large')
plt.show()
